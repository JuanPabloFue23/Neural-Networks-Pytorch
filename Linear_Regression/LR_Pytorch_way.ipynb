# %% [markdown]
# ## Stochastic Gradient Descent
#
# Unlike traditional gradient descent, which updates parameters using the entire dataset, SGD updates parameters using one sample at a time. This can lead to faster convergence.

# %%
import torch
w=torch.tensor(-15.0, requires_grad=True)
b=torch.tensor(-10.0, requires_grad=True)

X=torch.arange(-3,3,0.1).view(-1,1)
f=-3*X

import matplotlib.pyplot as plt
plt.plot(X.numpy(), f.numpy(), label='True Function')
plt.show()
# Out:
# c:\Users\juaaa\anaconda3\envs\entorno_pytorch\Lib\site-packages\torch\_subclasses\functional_tensor.py:279: UserWarning: Failed to initialize NumPy: No module named 'numpy' (Triggered internally at C:\actions-runner\_work\pytorch\pytorch\pytorch\torch\csrc\utils\tensor_numpy.cpp:84.)
#   cpu = _conversion_method_template(device=torch.device("cpu"))
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 8
#       5 X=torch.arange(-3,3,0.1).view(-1,1)
#       6 f=-3*X
# ----> 8 import matplotlib.pyplot as plt
#       9 plt.plot(X.numpy(), f.numpy(), label='True Function')
#      10 plt.show()
#
# File c:\Users\juaaa\anaconda3\envs\entorno_pytorch\Lib\site-packages\matplotlib\__init__.py:161
#     157 from packaging.version import parse as parse_version
#     159 # cbook must import matplotlib only within function
# ...

# %%
def forward(X):
    y=w*x+b
    return y

def criterion(yhat, y):
    return torch.mean((yhat - y)**2)
